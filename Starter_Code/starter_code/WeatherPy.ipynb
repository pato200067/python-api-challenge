# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Output file csv
output_data_file = "output_data/cities.csv"
output_data_df = pd.read_csv(output_data_file)

# %%
# DataFrame
output_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Base URL to work off                         
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Counter to go through data
record = 0
sets = 1

# Create DataFrame
city_df = pd.DataFrame({"City": cities})

city_df["Country"] = ""
city_df["Date"] = ""      
city_df["Latitude"] = ""
city_df["Longitude"] = ""
city_df["Cloudiness (%)"] = ""
city_df["Humidity (%)"] = ""
city_df["Max Temp (F)"] = ""
city_df["Wind Speed (mph)"] = ""


# Interate through Cities and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")


for index, row in weather_df.iterrows():
    
    city = row["City"]
    
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city
    weather_response = requests.get(query_url).json()
 
    try:
        print(f"Processing Record {record}  of Set {sets} | {city}.")
        #print (query_url) 
        
        city_df.loc[index, "Country"] = weather_response["sys"]["country"]     
        city_df.loc[index, "Date"] = datetime.datetime.fromtimestamp(weather_response["dt"])
        city_df.loc[index, "Latitude"] = weather_response["coord"]["lat"]
        city_df.loc[index, "Longitude"] = weather_response["coord"]["lon"]
        city_df.loc[index, "Cloudiness (%)"] = weather_response["clouds"]["all"]
        city_df.loc[index, "Humidity (%)"] = weather_response["main"]["humidity"]
        city_df.loc[index, "Max Temp (F)"] = 1.8 * (weather_response["main"]["temp_max"] - 273) + 32
        city_df.loc[index, "Wind Speed (mph)"] = weather_response["wind"]["speed"]
               
    except:
        print(f"City not found...skipping {city}.")
        #print (query_url) 
        
    
    record = record + 1
    if record == 50:
        record = 0
        sets = sets + 1 

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0  of Set 1 | edinburgh of the seven seas.
# City not found...skipping edinburgh of the seven seas.
# Processing Record 1  of Set 1 | ta`u.
# City not found...skipping ta`u.
# Processing Record 2  of Set 1 | port-aux-francais.
# City not found...skipping port-aux-francais.
# Processing Record 3  of Set 1 | hawaiian paradise park.
# City not found...skipping hawaiian paradise park.
# Processing Record 4  of Set 1 | utrik.
# City not found...skipping utrik.
# Processing Record 5  of Set 1 | waitangi.
# City not found...skipping waitangi.
# Processing Record 6  of Set 1 | puerto natales.
# City not found...skipping puerto natales.
# Processing Record 7  of Set 1 | arraial do cabo.
# City not found...skipping arraial do cabo.
# Processing Record 8  of Set 1 | buala.
# City not found...skipping buala.
# Processing Record 9  of Set 1 | talnakh.
# City not found...skipping talnakh.
# Processing Record 10  of Set 1 | petropavlovsk-kamchatsky.
# City not found...skipping petropavlovsk-kamchatsky.
# Processing Record 11  of Set 1 | kargasok.
# City not found...skipping kargasok.
# Processing Record 12  of Set 1 | las choapas.
# City not found...skipping las choapas.
# Processing Record 13  of Set 1 | kerikeri.
# City not found...skipping kerikeri.
# Processing Record 14  of Set 1 | albany.
# City not found...skipping albany.
# Processing Record 15  of Set 1 | kapyl'.
# City not found...skipping kapyl'.
# Processing Record 16  of Set 1 | bethel.
# City not found...skipping bethel.
# Processing Record 17  of Set 1 | tidjikja.
# City not found...skipping tidjikja.
# Processing Record 18  of Set 1 | papatowai.
# City not found...skipping papatowai.
# Processing Record 19  of Set 1 | olonkinbyen.
# City not found...skipping olonkinbyen.
# Processing Record 20  of Set 1 | minas de marcona.
# City not found...skipping minas de marcona.
# Processing Record 21  of Set 1 | adamstown.
# City not found...skipping adamstown.
# Processing Record 22  of Set 1 | remire-montjoly.
# City not found...skipping remire-montjoly.
# Processing Record 23  of Set 1 | st. john's.
# City not found...skipping st. john's.
# Processing Record 24  of Set 1 | saint-philippe.
# City not found...skipping saint-philippe.
# Processing Record 25  of Set 1 | huanta.
# City not found...skipping huanta.
# Processing Record 26  of Set 1 | sarny.
# City not found...skipping sarny.
# Processing Record 27  of Set 1 | novodvinsk.
# City not found...skipping novodvinsk.
# Processing Record 28  of Set 1 | ouellah.
# City not found...skipping ouellah.
# Processing Record 29  of Set 1 | puerto san carlos.
# City not found...skipping puerto san carlos.
# Processing Record 30  of Set 1 | grytviken.
# City not found...skipping grytviken.
# Processing Record 31  of Set 1 | kailua-kona.
# City not found...skipping kailua-kona.
# Processing Record 32  of Set 1 | hammerfest.
# City not found...skipping hammerfest.
# Processing Record 33  of Set 1 | yellowknife.
# City not found...skipping yellowknife.
# Processing Record 34  of Set 1 | elliot lake.
# City not found...skipping elliot lake.
# Processing Record 35  of Set 1 | boguchany.
# City not found...skipping boguchany.
# Processing Record 36  of Set 1 | turkmenbasy.
# City not found...skipping turkmenbasy.
# Processing Record 37  of Set 1 | howard springs.
# City not found...skipping howard springs.
# Processing Record 38  of Set 1 | ushuaia.
# City not found...skipping ushuaia.
# Processing Record 39  of Set 1 | avarua.
# City not found...skipping avarua.
# Processing Record 40  of Set 1 | canyon.
# City not found...skipping canyon.
# Processing Record 41  of Set 1 | sanctuary point.
# City not found...skipping sanctuary point.
# Processing Record 42  of Set 1 | whitehorse.
# City not found...skipping whitehorse.
# Processing Record 43  of Set 1 | chernyshevskiy.
# City not found...skipping chernyshevskiy.
# Processing Record 44  of Set 1 | west island.
# City not found...skipping west island.
# Processing Record 45  of Set 1 | pizarra.
# City not found...skipping pizarra.
# Processing Record 46  of Set 1 | lebu.
# City not found...skipping lebu.
# Processing Record 47  of Set 1 | iqaluit.
# City not found...skipping iqaluit.
# Processing Record 48  of Set 1 | rawson.
# City not found...skipping rawson.
# Processing Record 49  of Set 1 | chokwe.
# City not found...skipping chokwe.
# Processing Record 0  of Set 2 | kingston.
# City not found...skipping kingston.
# Processing Record 1  of Set 2 | mount gambier.
# City not found...skipping mount gambier.
# Processing Record 2  of Set 2 | gulf shores.
# City not found...skipping gulf shores.
# Processing Record 3  of Set 2 | puerto ayora.
# City not found...skipping puerto ayora.
# Processing Record 4  of Set 2 | atafu village.
# City not found...skipping atafu village.
# Processing Record 5  of Set 2 | glenrothes.
# City not found...skipping glenrothes.
# Processing Record 6  of Set 2 | chonchi.
# City not found...skipping chonchi.
# Processing Record 7  of Set 2 | maragogi.
# City not found...skipping maragogi.
# Processing Record 8  of Set 2 | san pedro pochutla.
# City not found...skipping san pedro pochutla.
# Processing Record 9  of Set 2 | bredasdorp.
# City not found...skipping bredasdorp.
# Processing Record 10  of Set 2 | port isabel.
# City not found...skipping port isabel.
# Processing Record 11  of Set 2 | tamanrasset.
# City not found...skipping tamanrasset.
# Processing Record 12  of Set 2 | la passe.
# City not found...skipping la passe.
# Processing Record 13  of Set 2 | college.
# City not found...skipping college.
# Processing Record 14  of Set 2 | taiohae.
# City not found...skipping taiohae.
# Processing Record 15  of Set 2 | sishilichengzi.
# City not found...skipping sishilichengzi.
# Processing Record 16  of Set 2 | istaravshan.
# City not found...skipping istaravshan.
# Processing Record 17  of Set 2 | thompson.
# City not found...skipping thompson.
# Processing Record 18  of Set 2 | sinabang.
# City not found...skipping sinabang.
# Processing Record 19  of Set 2 | san patricio.
# City not found...skipping san patricio.
# Processing Record 20  of Set 2 | invercargill.
# City not found...skipping invercargill.
# Processing Record 21  of Set 2 | muleshoe.
# City not found...skipping muleshoe.
# Processing Record 22  of Set 2 | carnarvon.
# City not found...skipping carnarvon.
# Processing Record 23  of Set 2 | montes claros.
# City not found...skipping montes claros.
# Processing Record 24  of Set 2 | ishigaki.
# City not found...skipping ishigaki.
# Processing Record 25  of Set 2 | cable beach.
# City not found...skipping cable beach.
# Processing Record 26  of Set 2 | balabac.
# City not found...skipping balabac.
# Processing Record 27  of Set 2 | kyustendil.
# City not found...skipping kyustendil.
# Processing Record 28  of Set 2 | port saint john's.
# City not found...skipping port saint john's.
# Processing Record 29  of Set 2 | bilibino.
# City not found...skipping bilibino.
# Processing Record 30  of Set 2 | port mathurin.
# City not found...skipping port mathurin.
# Processing Record 31  of Set 2 | tutoia.
# City not found...skipping tutoia.
# Processing Record 32  of Set 2 | georgetown.
# City not found...skipping georgetown.
# Processing Record 33  of Set 2 | glace bay.
# City not found...skipping glace bay.
# Processing Record 34  of Set 2 | san rafael.
# City not found...skipping san rafael.
# Processing Record 35  of Set 2 | baruun-urt.
# City not found...skipping baruun-urt.
# Processing Record 36  of Set 2 | zag.
# City not found...skipping zag.
# Processing Record 37  of Set 2 | rio grande.
# City not found...skipping rio grande.
# Processing Record 38  of Set 2 | new norfolk.
# City not found...skipping new norfolk.
# Processing Record 39  of Set 2 | kavaratti.
# City not found...skipping kavaratti.
# Processing Record 40  of Set 2 | eyl.
# City not found...skipping eyl.
# Processing Record 41  of Set 2 | progreso.
# City not found...skipping progreso.
# Processing Record 42  of Set 2 | talcahuano.
# City not found...skipping talcahuano.
# Processing Record 43  of Set 2 | hermanus.
# City not found...skipping hermanus.
# Processing Record 44  of Set 2 | enewetak.
# City not found...skipping enewetak.
# Processing Record 45  of Set 2 | antibes.
# City not found...skipping antibes.
# Processing Record 46  of Set 2 | devinuwara.
# City not found...skipping devinuwara.
# Processing Record 47  of Set 2 | taghazout.
# City not found...skipping taghazout.
# Processing Record 48  of Set 2 | jerome.
# City not found...skipping jerome.
# Processing Record 49  of Set 2 | jizan.
# City not found...skipping jizan.
# Processing Record 0  of Set 3 | dakhla.
# City not found...skipping dakhla.
# Processing Record 1  of Set 3 | mezhdurechenskiy.
# City not found...skipping mezhdurechenskiy.
# Processing Record 2  of Set 3 | bamboo flat.
# City not found...skipping bamboo flat.
# Processing Record 3  of Set 3 | agat village.
# City not found...skipping agat village.
# Processing Record 4  of Set 3 | shepetivka.
# City not found...skipping shepetivka.
# Processing Record 5  of Set 3 | longyearbyen.
# City not found...skipping longyearbyen.
# Processing Record 6  of Set 3 | ravar.
# City not found...skipping ravar.
# Processing Record 7  of Set 3 | port macquarie.
# City not found...skipping port macquarie.
# Processing Record 8  of Set 3 | tolanaro.
# City not found...skipping tolanaro.
# Processing Record 9  of Set 3 | cacador.
# City not found...skipping cacador.
# Processing Record 10  of Set 3 | fort bragg.
# City not found...skipping fort bragg.
# Processing Record 11  of Set 3 | sosua.
# City not found...skipping sosua.
# Processing Record 12  of Set 3 | punta arenas.
# City not found...skipping punta arenas.
# Processing Record 13  of Set 3 | dudinka.
# City not found...skipping dudinka.
# Processing Record 14  of Set 3 | al bawiti.
# City not found...skipping al bawiti.
# Processing Record 15  of Set 3 | blackmans bay.
# City not found...skipping blackmans bay.
# Processing Record 16  of Set 3 | coquimbo.
# City not found...skipping coquimbo.
# Processing Record 17  of Set 3 | nova sintra.
# City not found...skipping nova sintra.
# Processing Record 18  of Set 3 | kristiansund.
# City not found...skipping kristiansund.
# Processing Record 19  of Set 3 | chibougamau.
# City not found...skipping chibougamau.
# Processing Record 20  of Set 3 | margaret river.
# City not found...skipping margaret river.
# Processing Record 21  of Set 3 | crane.
# City not found...skipping crane.
# Processing Record 22  of Set 3 | fort mcmurray.
# City not found...skipping fort mcmurray.
# Processing Record 23  of Set 3 | harstad.
# City not found...skipping harstad.
# Processing Record 24  of Set 3 | serenje.
# City not found...skipping serenje.
# Processing Record 25  of Set 3 | posto fiscal rolim de moura.
# City not found...skipping posto fiscal rolim de moura.
# Processing Record 26  of Set 3 | alaghsas.
# City not found...skipping alaghsas.
# Processing Record 27  of Set 3 | wailua homesteads.
# City not found...skipping wailua homesteads.
# Processing Record 28  of Set 3 | olenino.
# City not found...skipping olenino.
# Processing Record 29  of Set 3 | ancud.
# City not found...skipping ancud.
# Processing Record 30  of Set 3 | turbat.
# City not found...skipping turbat.
# Processing Record 31  of Set 3 | barcelos.
# City not found...skipping barcelos.
# Processing Record 32  of Set 3 | tranovaho.
# City not found...skipping tranovaho.
# Processing Record 33  of Set 3 | saint-clement-de-riviere.
# City not found...skipping saint-clement-de-riviere.
# Processing Record 34  of Set 3 | luderitz.
# City not found...skipping luderitz.
# Processing Record 35  of Set 3 | taltal.
# City not found...skipping taltal.
# Processing Record 36  of Set 3 | port elizabeth.
# City not found...skipping port elizabeth.
# Processing Record 37  of Set 3 | kununurra.
# City not found...skipping kununurra.
# Processing Record 38  of Set 3 | governador valadares.
# City not found...skipping governador valadares.
# Processing Record 39  of Set 3 | namibe.
# City not found...skipping namibe.
# Processing Record 40  of Set 3 | osa.
# City not found...skipping osa.
# Processing Record 41  of Set 3 | mahomet.
# City not found...skipping mahomet.
# Processing Record 42  of Set 3 | sola.
# City not found...skipping sola.
# Processing Record 43  of Set 3 | la gi.
# City not found...skipping la gi.
# Processing Record 44  of Set 3 | iskateley.
# City not found...skipping iskateley.
# Processing Record 45  of Set 3 | lihue.
# City not found...skipping lihue.
# Processing Record 46  of Set 3 | i-n-salah.
# City not found...skipping i-n-salah.
# Processing Record 47  of Set 3 | kodiak.
# City not found...skipping kodiak.
# Processing Record 48  of Set 3 | tiksi.
# City not found...skipping tiksi.
# Processing Record 49  of Set 3 | sao felix do xingu.
# City not found...skipping sao felix do xingu.
# Processing Record 0  of Set 4 | qaqortoq.
# City not found...skipping qaqortoq.
# Processing Record 1  of Set 4 | waddan.
# City not found...skipping waddan.
# Processing Record 2  of Set 4 | moa.
# City not found...skipping moa.
# Processing Record 3  of Set 4 | ust'-ilimsk.
# City not found...skipping ust'-ilimsk.
# Processing Record 4  of Set 4 | nemuro.
# City not found...skipping nemuro.
# Processing Record 5  of Set 4 | gadzhiyevo.
# City not found...skipping gadzhiyevo.
# Processing Record 6  of Set 4 | east london.
# City not found...skipping east london.
# Processing Record 7  of Set 4 | koryazhma.
# City not found...skipping koryazhma.
# Processing Record 8  of Set 4 | port alfred.
# City not found...skipping port alfred.
# Processing Record 9  of Set 4 | xicotencatl.
# City not found...skipping xicotencatl.
# Processing Record 10  of Set 4 | ribeira grande.
# City not found...skipping ribeira grande.
# Processing Record 11  of Set 4 | sur.
# City not found...skipping sur.
# Processing Record 12  of Set 4 | yishui.
# City not found...skipping yishui.
# Processing Record 13  of Set 4 | torit.
# City not found...skipping torit.
# Processing Record 14  of Set 4 | anadyr.
# City not found...skipping anadyr.
# Processing Record 15  of Set 4 | bardai.
# City not found...skipping bardai.
# Processing Record 16  of Set 4 | sheregesh.
# City not found...skipping sheregesh.
# Processing Record 17  of Set 4 | brookings.
# City not found...skipping brookings.
# Processing Record 18  of Set 4 | lubao.
# City not found...skipping lubao.
# Processing Record 19  of Set 4 | egilsstadir.
# City not found...skipping egilsstadir.
# Processing Record 20  of Set 4 | srandakan.
# City not found...skipping srandakan.
# Processing Record 21  of Set 4 | funafuti.
# City not found...skipping funafuti.
# Processing Record 22  of Set 4 | kutum.
# City not found...skipping kutum.
# Processing Record 23  of Set 4 | olyokminsk.
# City not found...skipping olyokminsk.
# Processing Record 24  of Set 4 | tokar.
# City not found...skipping tokar.
# Processing Record 25  of Set 4 | korla.
# City not found...skipping korla.
# Processing Record 26  of Set 4 | kaa-khem.
# City not found...skipping kaa-khem.
# Processing Record 27  of Set 4 | freetown.
# City not found...skipping freetown.
# Processing Record 28  of Set 4 | hotan.
# City not found...skipping hotan.
# Processing Record 29  of Set 4 | phongsali.
# City not found...skipping phongsali.
# Processing Record 30  of Set 4 | hamilton.
# City not found...skipping hamilton.
# Processing Record 31  of Set 4 | homer.
# City not found...skipping homer.
# Processing Record 32  of Set 4 | san clemente del tuyu.
# City not found...skipping san clemente del tuyu.
# Processing Record 33  of Set 4 | alofi.
# City not found...skipping alofi.
# Processing Record 34  of Set 4 | fort st. john.
# City not found...skipping fort st. john.
# Processing Record 35  of Set 4 | intendente alvear.
# City not found...skipping intendente alvear.
# Processing Record 36  of Set 4 | carutapera.
# City not found...skipping carutapera.
# Processing Record 37  of Set 4 | klyuchi.
# City not found...skipping klyuchi.
# Processing Record 38  of Set 4 | stanley.
# City not found...skipping stanley.
# Processing Record 39  of Set 4 | bol.
# City not found...skipping bol.
# Processing Record 40  of Set 4 | howrah.
# City not found...skipping howrah.
# Processing Record 41  of Set 4 | afaahiti.
# City not found...skipping afaahiti.
# Processing Record 42  of Set 4 | kolwezi.
# City not found...skipping kolwezi.
# Processing Record 43  of Set 4 | hithadhoo.
# City not found...skipping hithadhoo.
# Processing Record 44  of Set 4 | vadso.
# City not found...skipping vadso.
# Processing Record 45  of Set 4 | franceville.
# City not found...skipping franceville.
# Processing Record 46  of Set 4 | palora.
# City not found...skipping palora.
# Processing Record 47  of Set 4 | vorgashor.
# City not found...skipping vorgashor.
# Processing Record 48  of Set 4 | kenai.
# City not found...skipping kenai.
# Processing Record 49  of Set 4 | fortuna.
# City not found...skipping fortuna.
# Processing Record 0  of Set 5 | nizhniy kuranakh.
# City not found...skipping nizhniy kuranakh.
# Processing Record 1  of Set 5 | badger.
# City not found...skipping badger.
# Processing Record 2  of Set 5 | mahibadhoo.
# City not found...skipping mahibadhoo.
# Processing Record 3  of Set 5 | mogadishu.
# City not found...skipping mogadishu.
# Processing Record 4  of Set 5 | papao.
# City not found...skipping papao.
# Processing Record 5  of Set 5 | kapuskasing.
# City not found...skipping kapuskasing.
# Processing Record 6  of Set 5 | lerwick.
# City not found...skipping lerwick.
# Processing Record 7  of Set 5 | camrose.
# City not found...skipping camrose.
# Processing Record 8  of Set 5 | thinadhoo.
# City not found...skipping thinadhoo.
# Processing Record 9  of Set 5 | kiunga.
# City not found...skipping kiunga.
# Processing Record 10  of Set 5 | porto novo.
# City not found...skipping porto novo.
# Processing Record 11  of Set 5 | caiaponia.
# City not found...skipping caiaponia.
# Processing Record 12  of Set 5 | touros.
# City not found...skipping touros.
# Processing Record 13  of Set 5 | kaohsiung.
# City not found...skipping kaohsiung.
# Processing Record 14  of Set 5 | aginskoye.
# City not found...skipping aginskoye.
# Processing Record 15  of Set 5 | walvis bay.
# City not found...skipping walvis bay.
# Processing Record 16  of Set 5 | beyneu.
# City not found...skipping beyneu.
# Processing Record 17  of Set 5 | tari.
# City not found...skipping tari.
# Processing Record 18  of Set 5 | fredericton.
# City not found...skipping fredericton.
# Processing Record 19  of Set 5 | orchomenos.
# City not found...skipping orchomenos.
# Processing Record 20  of Set 5 | mount pearl.
# City not found...skipping mount pearl.
# Processing Record 21  of Set 5 | essaouira.
# City not found...skipping essaouira.
# Processing Record 22  of Set 5 | 'ohonua.
# City not found...skipping 'ohonua.
# Processing Record 23  of Set 5 | isafjordur.
# City not found...skipping isafjordur.
# Processing Record 24  of Set 5 | sesimbra.
# City not found...skipping sesimbra.
# Processing Record 25  of Set 5 | daru.
# City not found...skipping daru.
# Processing Record 26  of Set 5 | siverek.
# City not found...skipping siverek.
# Processing Record 27  of Set 5 | dzuunmod.
# City not found...skipping dzuunmod.
# Processing Record 28  of Set 5 | labasa.
# City not found...skipping labasa.
# Processing Record 29  of Set 5 | khanty-mansiysk.
# City not found...skipping khanty-mansiysk.
# Processing Record 30  of Set 5 | zaozersk.
# City not found...skipping zaozersk.
# Processing Record 31  of Set 5 | childress.
# City not found...skipping childress.
# Processing Record 32  of Set 5 | charters towers.
# City not found...skipping charters towers.
# Processing Record 33  of Set 5 | mil'kovo.
# City not found...skipping mil'kovo.
# Processing Record 34  of Set 5 | longboat key.
# City not found...skipping longboat key.
# Processing Record 35  of Set 5 | rehoboth.
# City not found...skipping rehoboth.
# Processing Record 36  of Set 5 | wakkanai.
# City not found...skipping wakkanai.
# Processing Record 37  of Set 5 | flin flon.
# City not found...skipping flin flon.
# Processing Record 38  of Set 5 | belomorsk.
# City not found...skipping belomorsk.
# Processing Record 39  of Set 5 | guerrero negro.
# City not found...skipping guerrero negro.
# Processing Record 40  of Set 5 | north bend.
# City not found...skipping north bend.
# Processing Record 41  of Set 5 | bouarfa.
# City not found...skipping bouarfa.
# Processing Record 42  of Set 5 | tura.
# City not found...skipping tura.
# Processing Record 43  of Set 5 | rundu.
# City not found...skipping rundu.
# Processing Record 44  of Set 5 | eydhafushi.
# City not found...skipping eydhafushi.
# Processing Record 45  of Set 5 | flying fish cove.
# City not found...skipping flying fish cove.
# Processing Record 46  of Set 5 | jingdezhen.
# City not found...skipping jingdezhen.
# Processing Record 47  of Set 5 | say.
# City not found...skipping say.
# Processing Record 48  of Set 5 | primorsk.
# City not found...skipping primorsk.
# Processing Record 49  of Set 5 | angarsk.
# City not found...skipping angarsk.
# Processing Record 0  of Set 6 | gurupi.
# City not found...skipping gurupi.
# Processing Record 1  of Set 6 | villanueva del pardillo.
# City not found...skipping villanueva del pardillo.
# Processing Record 2  of Set 6 | lospalos.
# City not found...skipping lospalos.
# Processing Record 3  of Set 6 | san-pedro.
# City not found...skipping san-pedro.
# Processing Record 4  of Set 6 | smithers.
# City not found...skipping smithers.
# Processing Record 5  of Set 6 | polyarnyy.
# City not found...skipping polyarnyy.
# Processing Record 6  of Set 6 | meadow lake.
# City not found...skipping meadow lake.
# Processing Record 7  of Set 6 | pantai remis.
# City not found...skipping pantai remis.
# Processing Record 8  of Set 6 | oleksandrivka.
# City not found...skipping oleksandrivka.
# Processing Record 9  of Set 6 | mazagao.
# City not found...skipping mazagao.
# Processing Record 10  of Set 6 | bangjun.
# City not found...skipping bangjun.
# Processing Record 11  of Set 6 | portland.
# City not found...skipping portland.
# Processing Record 12  of Set 6 | weno.
# City not found...skipping weno.
# Processing Record 13  of Set 6 | kloulklubed.
# City not found...skipping kloulklubed.
# Processing Record 14  of Set 6 | inarajan village.
# City not found...skipping inarajan village.
# Processing Record 15  of Set 6 | nouadhibou.
# City not found...skipping nouadhibou.
# Processing Record 16  of Set 6 | al ghayzah.
# City not found...skipping al ghayzah.
# Processing Record 17  of Set 6 | port lincoln.
# City not found...skipping port lincoln.
# Processing Record 18  of Set 6 | moranbah.
# City not found...skipping moranbah.
# Processing Record 19  of Set 6 | mwene-ditu.
# City not found...skipping mwene-ditu.
# Processing Record 20  of Set 6 | ilulissat.
# City not found...skipping ilulissat.
# Processing Record 21  of Set 6 | kholmsk.
# City not found...skipping kholmsk.
# Processing Record 22  of Set 6 | selkirk.
# City not found...skipping selkirk.
# Processing Record 23  of Set 6 | champerico.
# City not found...skipping champerico.
# Processing Record 24  of Set 6 | uturoa.
# City not found...skipping uturoa.
# Processing Record 25  of Set 6 | buka.
# City not found...skipping buka.
# Processing Record 26  of Set 6 | sterling.
# City not found...skipping sterling.
# Processing Record 27  of Set 6 | tamiahua.
# City not found...skipping tamiahua.
# Processing Record 28  of Set 6 | nuevitas.
# City not found...skipping nuevitas.
# Processing Record 29  of Set 6 | santa rosa misiones.
# City not found...skipping santa rosa misiones.
# Processing Record 30  of Set 6 | okhotsk.
# City not found...skipping okhotsk.
# Processing Record 31  of Set 6 | colares.
# City not found...skipping colares.
# Processing Record 32  of Set 6 | cape coral.
# City not found...skipping cape coral.
# Processing Record 33  of Set 6 | okha.
# City not found...skipping okha.
# Processing Record 34  of Set 6 | lazaro cardenas.
# City not found...skipping lazaro cardenas.
# Processing Record 35  of Set 6 | rajaldesar.
# City not found...skipping rajaldesar.
# Processing Record 36  of Set 6 | udachny.
# City not found...skipping udachny.
# Processing Record 37  of Set 6 | shancheng.
# City not found...skipping shancheng.
# Processing Record 38  of Set 6 | ust-nera.
# City not found...skipping ust-nera.
# Processing Record 39  of Set 6 | jamestown.
# City not found...skipping jamestown.
# Processing Record 40  of Set 6 | cabo san lucas.
# City not found...skipping cabo san lucas.
# Processing Record 41  of Set 6 | san carlos.
# City not found...skipping san carlos.
# Processing Record 42  of Set 6 | hola.
# City not found...skipping hola.
# Processing Record 43  of Set 6 | rongelap.
# City not found...skipping rongelap.
# Processing Record 44  of Set 6 | nizhneudinsk.
# City not found...skipping nizhneudinsk.
# Processing Record 45  of Set 6 | peace river.
# City not found...skipping peace river.
# Processing Record 46  of Set 6 | tanjung pandan.
# City not found...skipping tanjung pandan.
# Processing Record 47  of Set 6 | asilah.
# City not found...skipping asilah.
# Processing Record 48  of Set 6 | purpe.
# City not found...skipping purpe.
# Processing Record 49  of Set 6 | young.
# City not found...skipping young.
# Processing Record 0  of Set 7 | pachino.
# City not found...skipping pachino.
# Processing Record 1  of Set 7 | beaudesert.
# City not found...skipping beaudesert.
# Processing Record 2  of Set 7 | vizinga.
# City not found...skipping vizinga.
# Processing Record 3  of Set 7 | sonsorol village.
# City not found...skipping sonsorol village.
# Processing Record 4  of Set 7 | hadibu.
# City not found...skipping hadibu.
# Processing Record 5  of Set 7 | burang.
# City not found...skipping burang.
# Processing Record 6  of Set 7 | akrehamn.
# City not found...skipping akrehamn.
# Processing Record 7  of Set 7 | vila velha.
# City not found...skipping vila velha.
# Processing Record 8  of Set 7 | sokcho.
# City not found...skipping sokcho.
# Processing Record 9  of Set 7 | kitimat.
# City not found...skipping kitimat.
# Processing Record 10  of Set 7 | ginir.
# City not found...skipping ginir.
# Processing Record 11  of Set 7 | salalah.
# City not found...skipping salalah.
# Processing Record 12  of Set 7 | nar'yan-mar.
# City not found...skipping nar'yan-mar.
# Processing Record 13  of Set 7 | taoudenni.
# City not found...skipping taoudenni.
# Processing Record 14  of Set 7 | strelka.
# City not found...skipping strelka.
# Processing Record 15  of Set 7 | happy valley-goose bay.
# City not found...skipping happy valley-goose bay.
# Processing Record 16  of Set 7 | zapala.
# City not found...skipping zapala.
# Processing Record 17  of Set 7 | babeni.
# City not found...skipping babeni.
# Processing Record 18  of Set 7 | hilo.
# City not found...skipping hilo.
# Processing Record 19  of Set 7 | tazacorte.
# City not found...skipping tazacorte.
# Processing Record 20  of Set 7 | midvagur.
# City not found...skipping midvagur.
# Processing Record 21  of Set 7 | pontianak.
# City not found...skipping pontianak.
# Processing Record 22  of Set 7 | maamba.
# City not found...skipping maamba.
# Processing Record 23  of Set 7 | kone.
# City not found...skipping kone.
# Processing Record 24  of Set 7 | nsanje.
# City not found...skipping nsanje.
# Processing Record 25  of Set 7 | ugoofaaru.
# City not found...skipping ugoofaaru.
# Processing Record 26  of Set 7 | quepos.
# City not found...skipping quepos.
# Processing Record 27  of Set 7 | ust-tsilma.
# City not found...skipping ust-tsilma.
# Processing Record 28  of Set 7 | omdurman.
# City not found...skipping omdurman.
# Processing Record 29  of Set 7 | adra.
# City not found...skipping adra.
# Processing Record 30  of Set 7 | cururupu.
# City not found...skipping cururupu.
# Processing Record 31  of Set 7 | kodinsk.
# City not found...skipping kodinsk.
# Processing Record 32  of Set 7 | konkwesso.
# City not found...skipping konkwesso.
# Processing Record 33  of Set 7 | port blair.
# City not found...skipping port blair.
# Processing Record 34  of Set 7 | ubinskoye.
# City not found...skipping ubinskoye.
# Processing Record 35  of Set 7 | canitas de felipe pescador.
# City not found...skipping canitas de felipe pescador.
# Processing Record 36  of Set 7 | yelan'.
# City not found...skipping yelan'.
# Processing Record 37  of Set 7 | filadelfia.
# City not found...skipping filadelfia.
# Processing Record 38  of Set 7 | gaiman.
# City not found...skipping gaiman.
# Processing Record 39  of Set 7 | la maddalena.
# City not found...skipping la maddalena.
# Processing Record 40  of Set 7 | taroa.
# City not found...skipping taroa.
# Processing Record 41  of Set 7 | mili.
# City not found...skipping mili.
# Processing Record 42  of Set 7 | ulsteinvik.
# City not found...skipping ulsteinvik.
# Processing Record 43  of Set 7 | brooks.
# City not found...skipping brooks.
# Processing Record 44  of Set 7 | medina de pomar.
# City not found...skipping medina de pomar.
# Processing Record 45  of Set 7 | hasaki.
# City not found...skipping hasaki.
# Processing Record 46  of Set 7 | carros.
# City not found...skipping carros.
# Processing Record 47  of Set 7 | susuman.
# City not found...skipping susuman.
# Processing Record 48  of Set 7 | prabumulih.
# City not found...skipping prabumulih.
# Processing Record 49  of Set 7 | al jawf.
# City not found...skipping al jawf.
# Processing Record 0  of Set 8 | yanqul.
# City not found...skipping yanqul.
# Processing Record 1  of Set 8 | vilyuchinsk.
# City not found...skipping vilyuchinsk.
# Processing Record 2  of Set 8 | pacific grove.
# City not found...skipping pacific grove.
# Processing Record 3  of Set 8 | kawthoung.
# City not found...skipping kawthoung.
# Processing Record 4  of Set 8 | christchurch.
# City not found...skipping christchurch.
# Processing Record 5  of Set 8 | wattegama.
# City not found...skipping wattegama.
# Processing Record 6  of Set 8 | colonia.
# City not found...skipping colonia.
# Processing Record 7  of Set 8 | kapa'a.
# City not found...skipping kapa'a.
# Processing Record 8  of Set 8 | mogocha.
# City not found...skipping mogocha.
# Processing Record 9  of Set 8 | necochea.
# City not found...skipping necochea.
# Processing Record 10  of Set 8 | avon.
# City not found...skipping avon.
# Processing Record 11  of Set 8 | menongue.
# City not found...skipping menongue.
# Processing Record 12  of Set 8 | inhambane.
# City not found...skipping inhambane.
# Processing Record 13  of Set 8 | lidkoping.
# City not found...skipping lidkoping.
# Processing Record 14  of Set 8 | inirida.
# City not found...skipping inirida.
# Processing Record 15  of Set 8 | north bondi.
# City not found...skipping north bondi.
# Processing Record 16  of Set 8 | yoakum.
# City not found...skipping yoakum.
# Processing Record 17  of Set 8 | peniche.
# City not found...skipping peniche.
# Processing Record 18  of Set 8 | burley.
# City not found...skipping burley.
# Processing Record 19  of Set 8 | porkhov.
# City not found...skipping porkhov.
# Processing Record 20  of Set 8 | tarnogskiy gorodok.
# City not found...skipping tarnogskiy gorodok.
# Processing Record 21  of Set 8 | nyurba.
# City not found...skipping nyurba.
# Processing Record 22  of Set 8 | hirara.
# City not found...skipping hirara.
# Processing Record 23  of Set 8 | ouesso.
# City not found...skipping ouesso.
# Processing Record 24  of Set 8 | severo-yeniseyskiy.
# City not found...skipping severo-yeniseyskiy.
# Processing Record 25  of Set 8 | puerto cabezas.
# City not found...skipping puerto cabezas.
# Processing Record 26  of Set 8 | thames.
# City not found...skipping thames.
# Processing Record 27  of Set 8 | san antonio de pale.
# City not found...skipping san antonio de pale.
# Processing Record 28  of Set 8 | bekovo.
# City not found...skipping bekovo.
# Processing Record 29  of Set 8 | princeville.
# City not found...skipping princeville.
# Processing Record 30  of Set 8 | domna.
# City not found...skipping domna.
# Processing Record 31  of Set 8 | codrington.
# City not found...skipping codrington.
# Processing Record 32  of Set 8 | itabirito.
# City not found...skipping itabirito.
# Processing Record 33  of Set 8 | nkurenkuru.
# City not found...skipping nkurenkuru.
# Processing Record 34  of Set 8 | jinxiang.
# City not found...skipping jinxiang.
# Processing Record 35  of Set 8 | milton-freewater.
# City not found...skipping milton-freewater.
# Processing Record 36  of Set 8 | ziro.
# City not found...skipping ziro.
# Processing Record 37  of Set 8 | langres.
# City not found...skipping langres.
# Processing Record 38  of Set 8 | svislach.
# City not found...skipping svislach.
# Processing Record 39  of Set 8 | tursunzoda.
# City not found...skipping tursunzoda.
# Processing Record 40  of Set 8 | billingham.
# City not found...skipping billingham.
# Processing Record 41  of Set 8 | ponte de sor.
# City not found...skipping ponte de sor.
# Processing Record 42  of Set 8 | nantucket.
# City not found...skipping nantucket.
# Processing Record 43  of Set 8 | churapcha.
# City not found...skipping churapcha.
# Processing Record 44  of Set 8 | bikenibeu village.
# City not found...skipping bikenibeu village.
# Processing Record 45  of Set 8 | toga village.
# City not found...skipping toga village.
# Processing Record 46  of Set 8 | petrozavodsk.
# City not found...skipping petrozavodsk.
# Processing Record 47  of Set 8 | el rosario.
# City not found...skipping el rosario.
# Processing Record 48  of Set 8 | kasane.
# City not found...skipping kasane.
# Processing Record 49  of Set 8 | cargados carajos.
# City not found...skipping cargados carajos.
# Processing Record 0  of Set 9 | coyhaique.
# City not found...skipping coyhaique.
# Processing Record 1  of Set 9 | yuba city.
# City not found...skipping yuba city.
# Processing Record 2  of Set 9 | mcrae.
# City not found...skipping mcrae.
# Processing Record 3  of Set 9 | huoqiu chengguanzhen.
# City not found...skipping huoqiu chengguanzhen.
# Processing Record 4  of Set 9 | palmer.
# City not found...skipping palmer.
# Processing Record 5  of Set 9 | villarrica.
# City not found...skipping villarrica.
# Processing Record 6  of Set 9 | santiago de cao.
# City not found...skipping santiago de cao.
# Processing Record 7  of Set 9 | tommot.
# City not found...skipping tommot.
# Processing Record 8  of Set 9 | liwale.
# City not found...skipping liwale.
# Processing Record 9  of Set 9 | mawlaik.
# City not found...skipping mawlaik.
# Processing Record 10  of Set 9 | bahia de kino.
# City not found...skipping bahia de kino.
# Processing Record 11  of Set 9 | bantval.
# City not found...skipping bantval.
# Processing Record 12  of Set 9 | sandakan.
# City not found...skipping sandakan.
# Processing Record 13  of Set 9 | dunedin.
# City not found...skipping dunedin.
# Processing Record 14  of Set 9 | argo.
# City not found...skipping argo.
# Processing Record 15  of Set 9 | jumla.
# City not found...skipping jumla.
# Processing Record 16  of Set 9 | aasiaat.
# City not found...skipping aasiaat.
# Processing Record 17  of Set 9 | kharp.
# City not found...skipping kharp.
# Processing Record 18  of Set 9 | palmwoods.
# City not found...skipping palmwoods.
# Processing Record 19  of Set 9 | manali.
# City not found...skipping manali.
# Processing Record 20  of Set 9 | narara.
# City not found...skipping narara.
# Processing Record 21  of Set 9 | leitchfield.
# City not found...skipping leitchfield.
# Processing Record 22  of Set 9 | lompoc.
# City not found...skipping lompoc.
# Processing Record 23  of Set 9 | molde.
# City not found...skipping molde.
# Processing Record 24  of Set 9 | khandyga.
# City not found...skipping khandyga.
# Processing Record 25  of Set 9 | ghat.
# City not found...skipping ghat.
# Processing Record 26  of Set 9 | sao vicente.
# City not found...skipping sao vicente.
# Processing Record 27  of Set 9 | verkhnevilyuysk.
# City not found...skipping verkhnevilyuysk.
# Processing Record 28  of Set 9 | watsa.
# City not found...skipping watsa.
# Processing Record 29  of Set 9 | isla vista.
# City not found...skipping isla vista.
# Processing Record 30  of Set 9 | constantia.
# City not found...skipping constantia.
# Processing Record 31  of Set 9 | ulladulla.
# City not found...skipping ulladulla.
# Processing Record 32  of Set 9 | lamar.
# City not found...skipping lamar.
# Processing Record 33  of Set 9 | kimbe.
# City not found...skipping kimbe.
# Processing Record 34  of Set 9 | tahe.
# City not found...skipping tahe.
# Processing Record 35  of Set 9 | flekkefjord.
# City not found...skipping flekkefjord.
# Processing Record 36  of Set 9 | vila franca do campo.
# City not found...skipping vila franca do campo.
# Processing Record 37  of Set 9 | haiku-pauwela.
# City not found...skipping haiku-pauwela.
# Processing Record 38  of Set 9 | kabompo.
# City not found...skipping kabompo.
# Processing Record 39  of Set 9 | mossel bay.
# City not found...skipping mossel bay.
# Processing Record 40  of Set 9 | madalena.
# City not found...skipping madalena.
# Processing Record 41  of Set 9 | gorontalo.
# City not found...skipping gorontalo.
# Processing Record 42  of Set 9 | tadine.
# City not found...skipping tadine.
# Processing Record 43  of Set 9 | bijie.
# City not found...skipping bijie.
# Processing Record 44  of Set 9 | gizo.
# City not found...skipping gizo.
# Processing Record 45  of Set 9 | verkhnedneprovskiy.
# City not found...skipping verkhnedneprovskiy.
# Processing Record 46  of Set 9 | jiangyou.
# City not found...skipping jiangyou.
# Processing Record 47  of Set 9 | kosh-agach.
# City not found...skipping kosh-agach.
# Processing Record 48  of Set 9 | tsiombe.
# City not found...skipping tsiombe.
# Processing Record 49  of Set 9 | gereida.
# City not found...skipping gereida.
# Processing Record 0  of Set 10 | yigo village.
# City not found...skipping yigo village.
# Processing Record 1  of Set 10 | perry hall.
# City not found...skipping perry hall.
# Processing Record 2  of Set 10 | rabaul.
# City not found...skipping rabaul.
# Processing Record 3  of Set 10 | mendi.
# City not found...skipping mendi.
# Processing Record 4  of Set 10 | damghan.
# City not found...skipping damghan.
# Processing Record 5  of Set 10 | el granada.
# City not found...skipping el granada.
# Processing Record 6  of Set 10 | goz beida.
# City not found...skipping goz beida.
# Processing Record 7  of Set 10 | ar rutbah.
# City not found...skipping ar rutbah.
# Processing Record 8  of Set 10 | sabang.
# City not found...skipping sabang.
# Processing Record 9  of Set 10 | salinas.
# City not found...skipping salinas.
# Processing Record 10  of Set 10 | myitkyina.
# City not found...skipping myitkyina.
# Processing Record 11  of Set 10 | leua.
# City not found...skipping leua.
# Processing Record 12  of Set 10 | navan.
# City not found...skipping navan.
# Processing Record 13  of Set 10 | kisangani.
# City not found...skipping kisangani.
# Processing Record 14  of Set 10 | gardez.
# City not found...skipping gardez.
# Processing Record 15  of Set 10 | biloela.
# City not found...skipping biloela.
# Processing Record 16  of Set 10 | sinan.
# City not found...skipping sinan.
# Processing Record 17  of Set 10 | saudarkrokur.
# City not found...skipping saudarkrokur.
# Processing Record 18  of Set 10 | timmins.
# City not found...skipping timmins.
# Processing Record 19  of Set 10 | swift current.
# City not found...skipping swift current.
# Processing Record 20  of Set 10 | atherton.
# City not found...skipping atherton.
# Processing Record 21  of Set 10 | cockburn town.
# City not found...skipping cockburn town.
# Processing Record 22  of Set 10 | puerto baquerizo moreno.
# City not found...skipping puerto baquerizo moreno.
# Processing Record 23  of Set 10 | chakari.
# City not found...skipping chakari.
# Processing Record 24  of Set 10 | dakoro.
# City not found...skipping dakoro.
# Processing Record 25  of Set 10 | le morne-rouge.
# City not found...skipping le morne-rouge.
# Processing Record 26  of Set 10 | gaspe.
# City not found...skipping gaspe.
# Processing Record 27  of Set 10 | kuanda.
# City not found...skipping kuanda.
# Processing Record 28  of Set 10 | la mira.
# City not found...skipping la mira.
# Processing Record 29  of Set 10 | shamsabad.
# City not found...skipping shamsabad.
# Processing Record 30  of Set 10 | olinda.
# City not found...skipping olinda.
# Processing Record 31  of Set 10 | khalilabad.
# City not found...skipping khalilabad.
# Processing Record 32  of Set 10 | piti village.
# City not found...skipping piti village.
# Processing Record 33  of Set 10 | saint george's.
# City not found...skipping saint george's.
# Processing Record 34  of Set 10 | cabedelo.
# City not found...skipping cabedelo.
# Processing Record 35  of Set 10 | yerofey pavlovich.
# City not found...skipping yerofey pavlovich.
# Processing Record 36  of Set 10 | la palma.
# City not found...skipping la palma.
# Processing Record 37  of Set 10 | mentekab.
# City not found...skipping mentekab.
# Processing Record 38  of Set 10 | bridgewater.
# City not found...skipping bridgewater.
# Processing Record 39  of Set 10 | barah.
# City not found...skipping barah.
# Processing Record 40  of Set 10 | port douglas.
# City not found...skipping port douglas.
# Processing Record 41  of Set 10 | naukseni.
# City not found...skipping naukseni.
# Processing Record 42  of Set 10 | margate.
# City not found...skipping margate.
# Processing Record 43  of Set 10 | villa gesell.
# City not found...skipping villa gesell.
# Processing Record 44  of Set 10 | santa marta.
# City not found...skipping santa marta.
# Processing Record 45  of Set 10 | changleng.
# City not found...skipping changleng.
# Processing Record 46  of Set 10 | yaren.
# City not found...skipping yaren.
# Processing Record 47  of Set 10 | fuvahmulah.
# City not found...skipping fuvahmulah.
# Processing Record 48  of Set 10 | ujae.
# City not found...skipping ujae.
# Processing Record 49  of Set 10 | vilyuysk.
# City not found...skipping vilyuysk.
# Processing Record 0  of Set 11 | broken hill.
# City not found...skipping broken hill.
# Processing Record 1  of Set 11 | maumere.
# City not found...skipping maumere.
# Processing Record 2  of Set 11 | yelizovo.
# City not found...skipping yelizovo.
# Processing Record 3  of Set 11 | narrabri.
# City not found...skipping narrabri.
# Processing Record 4  of Set 11 | praia da vitoria.
# City not found...skipping praia da vitoria.
# Processing Record 5  of Set 11 | winona.
# City not found...skipping winona.
# Processing Record 6  of Set 11 | esmeralda.
# City not found...skipping esmeralda.
# Processing Record 7  of Set 11 | fale old settlement.
# City not found...skipping fale old settlement.
# Processing Record 8  of Set 11 | puerto aysen.
# City not found...skipping puerto aysen.
# Processing Record 9  of Set 11 | leava.
# City not found...skipping leava.
# Processing Record 10  of Set 11 | suluova.
# City not found...skipping suluova.
# Processing Record 11  of Set 11 | novohrad-volynskyi.
# City not found...skipping novohrad-volynskyi.
# Processing Record 12  of Set 11 | saipan.
# City not found...skipping saipan.
# Processing Record 13  of Set 11 | pornic.
# City not found...skipping pornic.
# Processing Record 14  of Set 11 | pariaman.
# City not found...skipping pariaman.
# Processing Record 15  of Set 11 | rakops.
# City not found...skipping rakops.
# Processing Record 16  of Set 11 | fuyuan.
# City not found...skipping fuyuan.
# Processing Record 17  of Set 11 | infantes.
# City not found...skipping infantes.
# Processing Record 18  of Set 11 | san luis de la loma.
# City not found...skipping san luis de la loma.
# Processing Record 19  of Set 11 | leongatha.
# City not found...skipping leongatha.
# Processing Record 20  of Set 11 | revda.
# City not found...skipping revda.
# Processing Record 21  of Set 11 | mabinay.
# City not found...skipping mabinay.
# Processing Record 22  of Set 11 | yangjiang.
# City not found...skipping yangjiang.
# Processing Record 23  of Set 11 | sydney.
# City not found...skipping sydney.
# Processing Record 24  of Set 11 | porbandar.
# City not found...skipping porbandar.
# Processing Record 25  of Set 11 | am timan.
# City not found...skipping am timan.
# Processing Record 26  of Set 11 | nizhnesortymskiy.
# City not found...skipping nizhnesortymskiy.
# Processing Record 27  of Set 11 | quellon.
# City not found...skipping quellon.
# Processing Record 28  of Set 11 | nikolayevsk-on-amure.
# City not found...skipping nikolayevsk-on-amure.
# Processing Record 29  of Set 11 | tazovsky.
# City not found...skipping tazovsky.
# Processing Record 30  of Set 11 | joymontop.
# City not found...skipping joymontop.
# Processing Record 31  of Set 11 | krupki.
# City not found...skipping krupki.
# Processing Record 32  of Set 11 | kankanhalli.
# City not found...skipping kankanhalli.
# Processing Record 33  of Set 11 | es castell.
# City not found...skipping es castell.
# Processing Record 34  of Set 11 | tralee.
# City not found...skipping tralee.
# Processing Record 35  of Set 11 | patong.
# City not found...skipping patong.
# Processing Record 36  of Set 11 | ushtobe.
# City not found...skipping ushtobe.
# Processing Record 37  of Set 11 | pangai.
# City not found...skipping pangai.
# Processing Record 38  of Set 11 | rexburg.
# City not found...skipping rexburg.
# Processing Record 39  of Set 11 | clodomira.
# City not found...skipping clodomira.
# Processing Record 40  of Set 11 | saldanha.
# City not found...skipping saldanha.
# Processing Record 41  of Set 11 | upata.
# City not found...skipping upata.
# Processing Record 42  of Set 11 | guajara mirim.
# City not found...skipping guajara mirim.
# Processing Record 43  of Set 11 | nuuk.
# City not found...skipping nuuk.
# Processing Record 44  of Set 11 | mooloolaba.
# City not found...skipping mooloolaba.
# Processing Record 45  of Set 11 | shiguai.
# City not found...skipping shiguai.
# Processing Record 46  of Set 11 | st. paul.
# City not found...skipping st. paul.
# Processing Record 47  of Set 11 | shakawe.
# City not found...skipping shakawe.
# Processing Record 48  of Set 11 | la sarre.
# City not found...skipping la sarre.
# Processing Record 49  of Set 11 | cidreira.
# City not found...skipping cidreira.
# Processing Record 0  of Set 12 | sitka.
# City not found...skipping sitka.
# Processing Record 1  of Set 12 | port sudan.
# City not found...skipping port sudan.
# Processing Record 2  of Set 12 | dalianwan.
# City not found...skipping dalianwan.
# Processing Record 3  of Set 12 | amasra.
# City not found...skipping amasra.
# Processing Record 4  of Set 12 | pasighat.
# City not found...skipping pasighat.
# Processing Record 5  of Set 12 | mount isa.
# City not found...skipping mount isa.
# Processing Record 6  of Set 12 | cole harbour.
# City not found...skipping cole harbour.
# Processing Record 7  of Set 12 | kish.
# City not found...skipping kish.
# Processing Record 8  of Set 12 | rostov.
# City not found...skipping rostov.
# Processing Record 9  of Set 12 | pindushi.
# City not found...skipping pindushi.
# Processing Record 10  of Set 12 | bure.
# City not found...skipping bure.
# Processing Record 11  of Set 12 | miyako.
# City not found...skipping miyako.
# Processing Record 12  of Set 12 | torghay.
# City not found...skipping torghay.
# Processing Record 13  of Set 12 | uvinza.
# City not found...skipping uvinza.
# Processing Record 14  of Set 12 | gold camp.
# City not found...skipping gold camp.
# Processing Record 15  of Set 12 | shiyan.
# City not found...skipping shiyan.
# Processing Record 16  of Set 12 | leesville.
# City not found...skipping leesville.
# Processing Record 17  of Set 12 | kavieng.
# City not found...skipping kavieng.
# Processing Record 18  of Set 12 | morigaon.
# City not found...skipping morigaon.
# Processing Record 19  of Set 12 | kenora.
# City not found...skipping kenora.
# Processing Record 20  of Set 12 | naze.
# City not found...skipping naze.
# Processing Record 21  of Set 12 | lesina.
# City not found...skipping lesina.
# Processing Record 22  of Set 12 | souillac.
# City not found...skipping souillac.
# Processing Record 23  of Set 12 | tual.
# City not found...skipping tual.
# Processing Record 24  of Set 12 | alice springs.
# City not found...skipping alice springs.
# Processing Record 25  of Set 12 | santa isabel.
# City not found...skipping santa isabel.
# Processing Record 26  of Set 12 | vologda.
# City not found...skipping vologda.
# Processing Record 27  of Set 12 | kamaishi.
# City not found...skipping kamaishi.
# Processing Record 28  of Set 12 | liwonde.
# City not found...skipping liwonde.
# Processing Record 29  of Set 12 | arenapolis.
# City not found...skipping arenapolis.
# Processing Record 30  of Set 12 | vodnyy.
# City not found...skipping vodnyy.
# Processing Record 31  of Set 12 | nha trang.
# City not found...skipping nha trang.
# Processing Record 32  of Set 12 | gobabis.
# City not found...skipping gobabis.
# Processing Record 33  of Set 12 | dundee.
# City not found...skipping dundee.
# Processing Record 34  of Set 12 | zhalantun.
# City not found...skipping zhalantun.
# Processing Record 35  of Set 12 | laela.
# City not found...skipping laela.
# Processing Record 36  of Set 12 | general pico.
# City not found...skipping general pico.
# Processing Record 37  of Set 12 | yuzhno-kurilsk.
# City not found...skipping yuzhno-kurilsk.
# Processing Record 38  of Set 12 | talakan.
# City not found...skipping talakan.
# Processing Record 39  of Set 12 | ulety.
# City not found...skipping ulety.
# Processing Record 40  of Set 12 | kovur.
# City not found...skipping kovur.
# Processing Record 41  of Set 12 | canatlan.
# City not found...skipping canatlan.
# Processing Record 42  of Set 12 | nuku'alofa.
# City not found...skipping nuku'alofa.
# Processing Record 43  of Set 12 | aleksandrovskoye.
# City not found...skipping aleksandrovskoye.
# Processing Record 44  of Set 12 | anaconda.
# City not found...skipping anaconda.
# Processing Record 45  of Set 12 | elliot.
# City not found...skipping elliot.
# Processing Record 46  of Set 12 | inverloch.
# City not found...skipping inverloch.
# Processing Record 47  of Set 12 | bengkulu.
# City not found...skipping bengkulu.
# Processing Record 48  of Set 12 | tomatlan.
# City not found...skipping tomatlan.
# Processing Record 49  of Set 12 | choibalsan.
# City not found...skipping choibalsan.
# Processing Record 0  of Set 13 | amungan.
# City not found...skipping amungan.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df= pd.read_csv(output_data_file)

# %%
# Data Count
city_data_df.count()
# Out:
# City_ID       577
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       574
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#          City_ID.1         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                0         faya  18.3851   42.4509     22.06        35
# 1                1      farsund  58.0948    6.8047     13.30       100
# 2                2  new norfolk -42.7826  147.0587     11.72        58
# 3                3    jamestown  42.0970  -79.2353      5.77        77
# 4                4      lanzhou  36.0564  103.7922     14.53        48
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                21        2.60      SA  1666108228
# 1                 0        7.65      NO  1666108228
# 2                12        1.34      AU  1666108230
# 3               100        9.77      US  1666107934
# 4                59        1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
today = time.strftime("%m/%d/%Y")
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel('Max Temperature')
plt.title("City Latitude Vs Max Temperature ({today})")
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# The graph shows that temperature tends to drop as you move away from the equator

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
today = time.strftime("%m/%d/%Y")
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel('Humidity')
plt.title("City Latitude Vs Humidity ({today})")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
today = time.strftime("%m/%d/%Y")
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel('Cloudiness')
plt.title("City Latitude Vs Cloudiness ({today})")


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
today = time.strftime("%m/%d/%Y")
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel('Wind Speed')
plt.title("City Latitude Vs Wind Speed ({today})")


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
y = mx + c

# y is the dependent variable 
# m is the slope
# x is the independent variable
# c is the intercept

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0 )]

# Display sample data
northern_hemi_df.head()
# Out:
#          City_ID.1       City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                0       faya  18.3851   42.4509     22.06        35
# 1                1    farsund  58.0948    6.8047     13.30       100
# 3                3  jamestown  42.0970  -79.2353      5.77        77
# 4                4    lanzhou  36.0564  103.7922     14.53        48
# 6                6     albany  42.6001  -73.9662     10.36        74
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                21        2.60      SA  1666108228
# 1                 0        7.65      NO  1666108228
# 3               100        9.77      US  1666107934
# 4                59        1.20      CN  1666108230
# 6                29        2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0 )]

# Display sample data
southern_hemi_df.head()
# Out:
#          City_ID.1          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                2   new norfolk -42.7826  147.0587     11.72        58
# 5                5       ushuaia -54.8000  -68.3000      8.81        81
# 7                7     carnarvon -24.8667  113.6333     20.02        76
# 9                9  saint-pierre -21.3393   55.4781     22.82        68
# 10              10      colorado -22.8375  -51.9731     20.36        86
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                12        1.34      AU  1666108230
# 5                75        3.09      AR  1666108231
# 7                 0        7.46      AU  1666108232
# 9                 0        5.14      RE  1666108236
# 10               96        4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -0.51x + 33.71
# The r-squared is: -0.8462548186825364
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# Regression line equation is: y = 0.33x + 28.8
# The r-squared is: 0.6419546065421801

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# Regression line equation is: y = 0.33x + 28.8
# The r-squared is: 0.6419546065421801
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = 0.26x + 61.28
# The r-squared is: 0.2385317912939407
# The regression does not display much of a correlation between the data sets.

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.03x + 70.73
# The r-squared is: 0.016759316950056818
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
#
# Regression line equation is: y = 0.03x + 70.73
# The r-squared is: 0.016759316950056818
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.31x + 48.5
# The r-squared is: 0.155004893876971
# The regression does not display much of a correlation between the data sets.

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.39x + 67.02
# The r-squared is: 0.14341322916643243
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# Regression line equation is: y = 0.39x + 67.02
# The r-squared is: 0.14341322916643243
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.02x + 2.8
# The r-squared is: 0.17434667290903338
# The regression does not display much of a correlation between the data sets.

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.05x + 3.14
# The r-squared is: -0.24947753546264592
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
